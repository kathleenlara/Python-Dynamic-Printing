# %% [markdown]
# # Team 9
#
# Hello! We are Team 9. We want to introduce ourselves creatively, so we decided to do it like Tinder but for networking with an extra Madlib feature.
# We hope you like it and get to know us more!
#
# About the code:
# - We used a simple while and if-else statements across the source code to redirect t
#
#
# What needs to be improved:
# - Some input fields are still case sensitive
# - We need to add a function that corrects wrong input, for now please follow what is asked to be inputed
# - The user will need to input their data again when they want to find a new match
# - Some of our print statements look a little packed, and we could have used more functions for it to appear cleaner
# - Our variable naming can also be improved since we just chose random variables on top of our heads
#
#
# Enjoy!
#
# Alfredo Moura
#
# Alonso Gallegos
#
# Kathleen Lara
#
# Soledad Ibanez

# %%
# While statement that makes this source code continue to run while user keeps 
# typing y (yes) on the play again input

playAgain = "yes"
while playAgain == "yes":
    print("")

# simple datetime module that helps us get the time now so we can greet the user properly
    import datetime
    currentTime = datetime.datetime.now()
    currentTime.hour

# If function that means if hour of the day is less than 12 it's morning and so on..

    if currentTime.hour < 12: print('Good morning, welcome to TindIN!')
    elif 12 <= currentTime.hour < 18: print('Good afternoon, welcome to TindIN!')
    else: print('Good evening, welcome to TindIN!!')
   
    print("We'd like to set you up with a networking date with one of our members!")

    rules = input("Would you like an introduction of the team? yes/no: ")

# We used if else statements again here to redirect the users if they want to meet the whole team first
# or if they want to skip introduction and start meeting them
# We also used rules.lower function to convert the inputs to lower case everytime the user types upper case so input will still be valid


    if rules.lower() == "yes":
       print("""\n
       TindIN is a source code that you run and  choose your ideal person to have
       a networking date with. We have 4 awesome MBA graduates doing Dual Degree in 
       Business Analytics that you can choose to meet. TindIN will ask you a few questions 
       to make sure that you're going to be successful on this invitation process. 
       If it's a match, there is a surprise waiting for you. If not, don't worry - 
       you can learn more about the others. They are as excited to meet you as you are!""")
      
    
    else:
        print("\nAlright, let's find you a match!")

# This is where we do the madlib style we learned in class where we get some inputs from the user
    name = input('YOUR NAME: \t')
    school = input('YOUR SCHOOL: ')
    learn = input('WHAT YOU WOULD LIKE TO LEARN: ')
    food = input('YOUR FAVOURITE FOOD: ')
    restaurant = input ('YOUR FAVOURITE BOSTON RESTAURANT: ') 


    
# We used the inputs on this email template that we made

    print("*"*30)
    
    print("\n\nBefore you select your person, we prepared an email template to help you win this networking date! Keep it handy! ;)\n")
    print("-"*30)
    print(f"""\n
        Hello,\n 
        My name is {name}, I found your profile on TindIN and I’m currently looking to connect with 
        new students at {school}.  The moment I saw you on TindIN, 
        I couldn’t wait to email you and let you know how excited I am to meet you.  
        I would also love to learn more about {learn} and I hope you can teach 
        me about it. 
        
        I’m looking forward to meeting you, and I hope we can get together at {restaurant} on 
        Thursday next week. I really love {food}, I hope we can grab that on our first dinner together.
        
        I usually eat at around 7PM, so I hope you would be willing to skip Professor’s class to meet with me.
        
        Regards,
        {name}""")
    
    
    input(prompt= "< Press Enter to Continue > ")
    
    
    print("-"*30)
    
    print("\n\nWhat type of person would you like to connect with from the team?")
    print("A - Geek who thinks he/she's funny but not really")
    print("B - Business executive who probably has his/her life sorted out")
    print("C - Outgoing bachelor who is great at salsa")
    print("D - Numbers guy/gal who doesn't always have a calculator")
    
    
# We asked the user who they want to meet here and then we run another if else statement to redirect the users
    question1 = input("Who would you like to meet from the above? Pick one: A/B/C/D ")

# Our main if else statement here is redirecting to the person the user chooses
# We have a sub if else statement every person that asks if the person they choose is a right match
# We used .upper() function here to convert any input to upper case so answer will be valid

    if question1.upper() == "A":
        print("\n\n")
        print("*"*30)
        print("""\nMeet Kathleen Lara\nHi I'm Kat! I'm a Product Analyst from the Philippines. I speak 7 languages, and my favourite is unfortunately not english nor tagalog but JavaScript and Python. I like playing board games and crying myself to sleep everytime I lose. Unlike others, I find comfort in awkward silence. Weird? I know. \n\n""")
        print("*"*30)
        
        question2 = input("Before you send that email, do you think it's a match? yes/no ")
        
        if question2.lower() == "yes":
            print("\nWeee! Here's your surprise, yes it's her email: klara2019@student.hult.edu\nHappy Networking!\n")
            playAgain = input("Do you want to try it again?:(yes/no)")
          
        else:
            print("\nKk, let's do this again!\n")
            
        
    if question1.upper() == "B":
        print("\n\n")
        print("*"*30)
        print("""\nMeet Sole Ibanez.\n\nHi! Sole from Chile here!\nI'm a Marketing Executive with 15+ years of experience in Latin America (started young).\nMy focus is on Media & CPG but no matter the industry, I love to explore new ways to do business,\nmeaning new forms to work, new markets, new products, whatever is needed considering the moment, and the objective.\nIn my free time, I like to watch films, take photos, and dream about diving with sharks!\nDo you think we match? Let's connect!\n\n""")
        print("*"*30)
        
        question2 = input("Before you send that email, do you think it's a match? yes/no ")
        
        if question2.lower() == "yes":
            print("\nWeee! Here's your surprise, yes it's her email: sibanez2019@student.hult.edu\nHappy Networking!\n")
            print("")
            playAgain = input("Do you want to try it again?:(yes/no)")
          
        else:
            print("\nKk, let's do this again\n")
            
    
    if question1.upper() == "C":
        print("\n\n")
        print("*"*30)
        print("""\nMeet Alonso Gallegos.\n\nHi, my name is Alonso! I'm from Peru, the land of Ceviche and Macchu Picchu!\nI have worked in many Tech industries in the past, especially in automation and security.\nMy goal now is to connect and get into the start-up tech world.\nMy dream is to travel around the world and learn about the innovations happening everywhere.\nLet's connect!\n\n""")
        print("*"*30)
        
        question2 = input("Before you send that email, do you think it's a match? yes/no ")
        
        if question2.lower() == "yes":
            print("\nWeee! Here's your surprise, yes it's his email: cgallegos2019@student.hult.edu\nHappy Networking!\n")
            playAgain = input("Do you want to try it again?:(yes/no)")
            
        else:
            print("\nKk, let's do this again\n")
        
    if question1.upper() == "D":
        print("\n\n")
        print("*"*30)
        print("""\nMeet Alfredo Moura.\n\nHi, my name is Alfredo! I'm from Brazil, the land of the famous açaí!\nMy goal is to start my own company and travel to each and every country on this planet.\nI would love to discuss some ideas! Let's meet!\n\n""")
        print("*"*30)
        
        question2 = input("Before you send that email, do you think it's a match? yes/no ")
        
        if question2.lower() == "yes":
            print("\nWeee! Here's your surprise, yes it's his email: amoura2019@student.hult.edu\nHappy Networking!\n")
            playAgain = input("Do you want to try it again?:(yes/no)")
          
            
        else:
            print("Kk, let's do this again\n")
